# %% [markdown]
# <a href="https://colab.research.google.com/github/RostislavB74/DS_HW2/blob/main/HW2_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bestsellers with categories.csv')
df.head(550)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
print('рядки','колонки')
df.shape
# Out:
# рядки колонки
# (550, 7)

# %%
df.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']

# %%
list(df.head())
# Out:
# ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']

# %% [markdown]
# Відповідь: Про скільки книг зберігає дані датасет?
# В таблиці представлено 550 записів в період з 2009 по 2019 роки по ТОП-50 книг за кожен рік
# якщо дивитися скільки книг за номенклатурою, то це 351 унікальний запис

# %%
df_copy=df.copy()

# %%
list(df_copy.head())
# Out:
# ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']

# %%
df_copy = df_copy.groupby('name')
pd.pivot_table(df, index = ['name'])
# Out:
# <ipython-input-62-aee3272bb62d>:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df, index = ['name'])
#                                                     price  reviews  \
# name
# 10-Day Green Smoothie Cleanse                         8.0  17350.0
# 11/22/63: A Novel                                    22.0   2052.0
# 12 Rules for Life: An Antidote to Chaos              15.0  18979.0
# 1984 (Signet Classics)                                6.0  21424.0
# 5,000 Awesome Facts (About Everything!) (Nation...   12.0   7665.0
# ...                                                   ...      ...
# Winter of the World: Book Two of the Century Tr...   15.0  10760.0
# Women Food and God: An Unexpected Path to Almos...   11.0   1302.0
# Wonder                                                9.0  21625.0
# ...

# %%
#Перевірте, чи у всіх рядків вистачає даних: виведіть кількість пропусків (na) у кожному зі стовпців (використовуйте функції isna та sum)
missing_values = df.isnull().sum()
# Підрахунок частки пропущених значень в кожній колонці
total_rows = len(df)
missing_percentage = (missing_values / total_rows) * 100
# Виведемо результати
print("Кількість пропусків в кожній колонці:")
# print(missing_percentage.round(2))
print(missing_values)
# Out:
# Кількість пропусків в кожній колонці:
# name           0
# author         0
# user_rating    0
# reviews        0
# price          0
# year           0
# genre          0
# dtype: int64

# %% [markdown]
# Відповідь: Чи є в якихось змінних пропуски? (Так / ні)** Ні пропусків немає**

# %%
list(df.head())
# Out:
# ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']

# %%
df.head(5)
# Out:
#                                                 name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      author  user_rating  reviews  price  year        genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
##Перевірте, які є унікальні значення в колонці genre (використовуйте функцію unique)
df.genre.unique ()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# Відповідь: Які є унікальні жанри? Всього два жанри Fiction (художня література) і Non Fiction

# %%
#Тепер подивіться на розподіл цін: побудуйте діаграму (використовуйте kind='hist')
df_copy.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
# %matplotlib inline
list(df_copy.head())
# Out:
# ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.figure(figsize=(10, 6))
df_copy['price'].plot(kind='hist', bins=50, alpha=0.8, color='skyblue', edgecolor='black')
plt.title('Розподіл цін на книги')
plt.xlabel('Ціна')
plt.ylabel('Кількість книг')
plt.grid(True)
plt.show()

# %%
#Визначте, яка ціна у нас максимальна, мінімальна, середня, медіанна (використовуйте функції max, min, mean, median)
agg_func_math = {
    'price': ['min', 'max', 'mean', 'median']
}
df_copy.agg(agg_func_math).round(2)
# Out:
#                                                    price
#                                                      min max  mean median
# name
# 10-Day Green Smoothie Cleanse                          8   8   8.0    8.0
# 11/22/63: A Novel                                     22  22  22.0   22.0
# 12 Rules for Life: An Antidote to Chaos               15  15  15.0   15.0
# 1984 (Signet Classics)                                 6   6   6.0    6.0
# 5,000 Awesome Facts (About Everything!) (Nation...    12  12  12.0   12.0
# ...                                                  ...  ..   ...    ...
# Winter of the World: Book Two of the Century Tr...    15  15  15.0   15.0
# Women Food and God: An Unexpected Path to Almos...    11  11  11.0   11.0
# Wonder                                                 9   9   9.0    9.0
# Wrecking Ball (Diary of a Wimpy Kid Book 14)           8   8   8.0    8.0
# You Are a Badass: How to Stop Doubting Your Gre...     8   8   8.0    8.0
#
# ...

# %% [markdown]
# Відповідь: Максимальна ціна? 105
# Відповідь: Мінімальна ціна? 0
# Відповідь: Середня ціна? 13.1
# Відповідь: Медіанна ціна? 11.0

# %%
max_ratings = df.groupby('name')['user_rating'].max()
max_rating_value = max_ratings.max()
count_max_rating = (max_ratings == max_rating_value).sum()
print(f"Кількість записів з найвищим рейтингом ({max_rating_value}): {count_max_rating}")
# Out:
# Кількість записів з найвищим рейтингом (4.9): 28

# %% [markdown]
# Відповідь: Який рейтинг у датасеті найвищий? Відповідь: 4.9
#
# Відповідь: Скільки книг мають такий рейтинг? Відповідь: 28

# %%
max_ratings = df.groupby('name')['reviews'].max()
max_rating_value = max_ratings.max()
count_max_rating = (max_ratings == max_rating_value).sum()
print(f"Кількість відгуків з найвищим рейтингом ({max_rating_value}): {count_max_rating}")
# Out:
# Кількість відгуків з найвищим рейтингом (87841): 1

# %% [markdown]
# Відповідь: Яка книга має найбільше відгуків? Відповідь: 1

# %%
data_2015 = df[df['year'] == 2015]
max_price_2015 = data_2015['price'].max()
count_max_price_2015 = (data_2015['price'] == max_price_2015).sum()
max_price_book_2015 = data_2015[data_2015['price'] == max_price_2015]['name'].iloc[0]

print(f"Книга з найвищою ціною за 2015 рік: {max_price_book_2015} - Ціна: {max_price_2015}, Кількість: {count_max_price_2015}")
# Out:
# Книга з найвищою ціною за 2015 рік: Publication Manual of the American Psychological Association, 6th Edition - Ціна: 46, Кількість: 1

# %% [markdown]
# Відповідь: З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча? Відповідь:Manual of the American Psychological Association, 6th Edition - Ціна: 46, Кількість: 1

# %%
data_2010 = df[(df['year'] == 2010) & (df['genre'] == 'Fiction')]

count_2010 = len(data_2010)

print(f"За 2010 рік до Топ-50 потрапило {count_2010} книг жанру Fiction")
# Out:
# За 2010 рік до Топ-50 потрапило 20 книг жанру Fiction

# %% [markdown]
# Відповідь: Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році (використовуйте &)? Відповідь: 20

# %%
data_2010_11 = df[(df['year'] >= 2010) & (df['year'] <= 2011) & (df['user_rating'] == 4.9)]

count_2010_11 = len(data_2010_11)

print(f"За 2010-2011 роки до Топ-50 потрапило {count_2010_11} книг з рейтингом 4.9")
# Out:
# За 2010-2011 роки до Топ-50 потрапило 1 книг з рейтингом 4.9

# %% [markdown]
# Відповідь: Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або функцію isin)? Відповідь: 1 книга

# %%
years_range = range(2010, 2012)
ratings_to_check = [4.9]
data_10_11 = df[df['year'].isin(years_range) & df['user_rating'].isin(ratings_to_check)]

# count_10_11 = len(data_10_11)
# list(df_copy.head())
print(f"За 2010-2011 роки до Топ-50 потрапило {count_2010_11} книг з рейтингом 4.9")
# Out:
# За 2010-2011 роки до Топ-50 потрапило 1 книг з рейтингом 4.9

# %%
data_2015 = df[(df['year'] >= 2015) & (df['year'] < 2016) & (df['price'] < 8)]
data_2015.sort_values('price')
# Out:
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 123                               Giraffes Can't Dance       Giles Andreae
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 478                        The Very Hungry Caterpillar          Eric Carle
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 28                        Baby Touch and Feel: Animals                  DK
# ...

# %% [markdown]
# І насамкінець, давайте відсортуємо за зростанням ціни всі книги, які потрапили до рейтингу в 2015 році і коштують дешевше за 8 доларів (використовуйте функцію sort_values).
# Відповідь: Яка книга остання у відсортованому списку? Відповідь:
# Old School (Diary of a Wimpy Kid #10)	Jeff Kinney	4.8	6169	7	2015	Fiction

# %% [markdown]
# Агрегування даних та з'єднання таблиць
# Остання секція цього домашнього завдання включає просунутіші функції. Але не хвилюйтеся, pandas робить усі операції простими та зрозумілими.

# %%
#Для початку давайте подивимося на максимальну та мінімальну ціни для кожного з
# жанрів (використовуйте функції groupby та agg, для підрахунку мінімальних та
# максимальних значень використовуйте max та min). Не беріть усі стовпці,
# виберіть тільки потрібні вам
agg_func_math = {
    'price': ['min', 'max'],

}
result = df.groupby(['genre']).agg(agg_func_math)
print(result)
# df_copy.agg(agg_func_math).round(2)
# Out:
#             price
#               min  max
# genre
# Fiction         0   82
# Non Fiction     0  105

# %% [markdown]
# Відповідь: Максимальна ціна для жанру Fiction: 82
#
# Відповідь: Мінімальна ціна для жанру Fiction: 0
#
# Відповідь: Максимальна ціна для жанру Non Fiction: 105
#
# Відповідь: Мінімальна ціна для жанру Non Fiction: 0

# %%
#Тепер створіть новий датафрейм, який вміщатиме кількість книг
#для кожного з авторів (використовуйте функції groupby та agg, для
#підрахунку кількості використовуйте count).
#Не беріть усі стовпці, виберете тільки потрібні
# df_copy.columns.tolist()
# agg_func_count = {
df_new = df.copy()
columns_to_keep = ['name', 'author']
df_new = df_new[columns_to_keep]
df_new.columns.tolist()
# Out:
# ['name', 'author']

# %%
df_quantity = df_new.groupby('author').size().reset_index(name='кількість книг')

df_quantity.sort_values('кількість книг')
# Out:
#                                  author  кількість книг
# 123                          Jill Twiss               1
# 178                      Patrick Thorpe               1
# 109                   Ian K. Smith M.D.               1
# 108                        Howard Stern               1
# 107                     Hopscotch Girls               1
# ..                                  ...             ...
# 11   American Psychological Association              10
# 226                     Suzanne Collins              11
# 92                         Gary Chapman              11
# 197                        Rick Riordan              11
# 120                         Jeff Kinney              12
#
# [248 rows x 2 columns]

# %%
df_quantity.head()
# Out:
#                        author  кількість книг
# 0            Abraham Verghese               2
# 1              Adam Gasiewski               1
# 2               Adam Mansbach               1
# 3                   Adir Levy               1
# 4  Admiral William H. McRaven               1

# %% [markdown]
# Відповідь: Якої розмірності вийшла таблиця? Відповідь:248x2
#
# Відповідь: Який автор має найбільше книг? Відповідь: Jeff Kinney
#
# Відповідь: Скільки книг цього автора? Відповідь: 12

# %%
#Тепер створіть другий датафрейм, який буде вміщати середній рейтинг
#для кожного автора (використовуйте функції groupby та agg,
#для підрахунку середнього значення використовуйте mean).
#Не беріть усі стовпці, виберете тільки потрібні
df_new_rating = df.copy()
columns_to_keep = ['author','user_rating']
df_new_rating = df_new_rating[columns_to_keep]
df_new_rating.columns.tolist()
# Out:
# ['author', 'user_rating']

# %%
df_avr = df_new_rating.groupby('author')['user_rating'].mean()

df_avr.sort_values()
# Out:
# author
# Donna Tartt           3.9
# Gillian Flynn         4.0
# Muriel Barbery        4.0
# Gallup                4.0
# Ian K. Smith M.D.     4.1
#                      ...
# Lin-Manuel Miranda    4.9
# Patrick Thorpe        4.9
# Nathan W. Pyle        4.9
# Bill Martin Jr.       4.9
# Jill Twiss            4.9
# Name: user_rating, Length: 248, dtype: float64

# %%
average_rating_by_author = df_new_rating.groupby('author')['user_rating'].mean()
result_avg =average_rating_by_author.sort_values()
result_avg = result_avg.reset_index()
result_avg.columns = ['author', 'середній рейтинг']
# result_avg = result_avg.groupby('author').size().reset_index(name='avg')

# result_avg.sort_values('author')

# %% [markdown]
# Відповідь: У якого автора середній рейтинг мінімальний? Відповідь: Donna Tartt
#
# Відповідь: Який у цього автора середній рейтинг? Відповідь:3.9

# %%
result_avg.round(2)
# Out:
#                  author  середній рейтинг
# 0           Donna Tartt               3.9
# 1         Gillian Flynn               4.0
# 2        Muriel Barbery               4.0
# 3                Gallup               4.0
# 4     Ian K. Smith M.D.               4.1
# ..                  ...               ...
# 243  Lin-Manuel Miranda               4.9
# 244      Patrick Thorpe               4.9
# 245      Nathan W. Pyle               4.9
# 246     Bill Martin Jr.               4.9
# 247          Jill Twiss               4.9
#
# [248 rows x 2 columns]

# %%
df_quantity
# Out:
#                          author  кількість книг
# 0              Abraham Verghese               2
# 1                Adam Gasiewski               1
# 2                 Adam Mansbach               1
# 3                     Adir Levy               1
# 4    Admiral William H. McRaven               1
# ..                          ...             ...
# 243             Walter Isaacson               3
# 244               William Davis               2
# 245            William P. Young               2
# 246            Wizards RPG Team               3
# 247                Zhi Gang Sha               2
#
# [248 rows x 2 columns]

# %%
result_concat = pd.concat([df_quantity.set_index('author'), result_avg.set_index('author')], axis=1)

# %%
result_concat.round(2)
# Out:
#                             кількість книг  середній рейтинг
# author
# Abraham Verghese                         2              4.60
# Adam Gasiewski                           1              4.40
# Adam Mansbach                            1              4.80
# Adir Levy                                1              4.80
# Admiral William H. McRaven               1              4.70
# ...                                    ...               ...
# Walter Isaacson                          3              4.57
# William Davis                            2              4.40
# William P. Young                         2              4.60
# Wizards RPG Team                         3              4.80
# Zhi Gang Sha                             2              4.60
#
# [248 rows x 2 columns]

# %%
result_concat.sort_values('середній рейтинг')
# Out:
#                     кількість книг  середній рейтинг
# author
# Donna Tartt                      2               3.9
# Gillian Flynn                    3               4.0
# Muriel Barbery                   1               4.0
# Gallup                           9               4.0
# Ian K. Smith M.D.                1               4.1
# ...                            ...               ...
# Lin-Manuel Miranda               1               4.9
# Patrick Thorpe                   1               4.9
# Nathan W. Pyle                   1               4.9
# Bill Martin Jr.                  2               4.9
# Jill Twiss                       1               4.9
#
# [248 rows x 2 columns]

# %%
#З'єднайте останні два датафрейми так, щоб для кожного автора
#було видно кількість книг та середній рейтинг
#(Використовуйте функцію concat з параметром axis=1)
result_summ=result_concat.sort_values('кількість книг')
print(result_summ.round(2))
# Out:
#                                     кількість книг  середній рейтинг
# author
# Jill Twiss                                       1              4.90
# Patrick Thorpe                                   1              4.90
# Ian K. Smith M.D.                                1              4.10
# Howard Stern                                     1              4.30
# Hopscotch Girls                                  1              4.80
# ...                                            ...               ...
# American Psychological Association              10              4.50
# Suzanne Collins                                 11              4.66
# Gary Chapman                                    11              4.74
# Rick Riordan                                    11              4.77
# Jeff Kinney                                     12              4.80
#
# [248 rows x 2 columns]

# %%
#Відсортуйте датафрейм за зростаючою кількістю книг
#та зростаючим рейтингом (використовуйте функцію sort_values)

result_concat = result_concat.sort_values(by=['кількість книг', 'середній рейтинг'], ascending=[True, True])
print(result_concat.round(2))
# Out:
#                                     кількість книг  середній рейтинг
# author
# Muriel Barbery                                   1              4.00
# Chris Cleave                                     1              4.10
# Ian K. Smith M.D.                                1              4.10
# Pierre Dukan                                     1              4.10
# Elizabeth Strout                                 1              4.20
# ...                                            ...               ...
# American Psychological Association              10              4.50
# Suzanne Collins                                 11              4.66
# Gary Chapman                                    11              4.74
# Rick Riordan                                    11              4.77
# Jeff Kinney                                     12              4.80
#
# [248 rows x 2 columns]

# %% [markdown]
# Відповідь: Який автор перший у списку? Muriel Barbery                      171               1          4.00

# %%
result_concat
# Out:
#                                     кількість книг  середній рейтинг
# author
# Muriel Barbery                                   1          4.000000
# Chris Cleave                                     1          4.100000
# Ian K. Smith M.D.                                1          4.100000
# Pierre Dukan                                     1          4.100000
# Elizabeth Strout                                 1          4.200000
# ...                                            ...               ...
# American Psychological Association              10          4.500000
# Suzanne Collins                                 11          4.663636
# Gary Chapman                                    11          4.736364
# Rick Riordan                                    11          4.772727
# Jeff Kinney                                     12          4.800000
#
# [248 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
plt.figure(figsize=(10, 6))
result_concat['середній рейтинг'].plot(kind='hist', bins=28, alpha=1, color='y', edgecolor='black')
plt.title('Середній рейтинг')
plt.xlabel('ціна')
plt.ylabel('Кількість книг')
plt.grid(True)
plt.show()

# %%
sns.lineplot(data=df['price'])
plt.title('Коливання ціни')
plt.xlabel('Кількість книг')
plt.ylabel('Ціна')
plt.grid(True)
plt.show()

# %%
authors_per_year = df.groupby('year')['author'].nunique()
print(authors_per_year)
# Out:
# year
# 2009    39
# 2010    43
# 2011    45
# 2012    42
# 2013    47
# 2014    44
# 2015    44
# 2016    47
# 2017    49
# 2018    46
# 2019    47
# Name: author, dtype: int64

# %%
import matplotlib.pyplot as plt

# authors_per_year містить кількість унікальних авторів за кожен рік
plt.figure(figsize=(10, 6))
authors_per_year.plot(kind='bar', color='y')
plt.title('Кількість унікальних авторів за роками')
plt.xlabel('Рік')
plt.ylabel('Кількість унікальних авторів')
plt.xticks(rotation=90)  # Повернення підписів осі X
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
authors_per_year.plot(kind='line', marker='o', color='green')
plt.title('Кількість унікальних авторів за роками')
plt.xlabel('Рік')
plt.ylabel('Кількість унікальних авторів')
plt.xticks(rotation=45)  # Повернення підписів осі X
plt.grid()
plt.show()
