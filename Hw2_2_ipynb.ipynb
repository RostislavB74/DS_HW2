# %% [markdown]
# <a href="https://colab.research.google.com/github/RostislavB74/DS_HW2/blob/main/Hw2_2_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv
import pandas as pd
import numpy as np
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2017_jun_final.csv')
df_copy =df.copy()

# %% [markdown]
# # Новый раздел

# %%
#Прочитайте отриману таблицю, використовуючи метод head
list(df.head())
# Out:
# ['N',
#  'Должность',
#  'Язык.программирования',
#  'Специализация',
#  'Общий.опыт.работы',
#  'Опыт.работы.на.текущем.месте',
#  'Зарплата.в.месяц',
#  'Изменение.зарплаты.за.12.месяцев',
#  'Город',
#  'Размер.компании',
#  'Тип.компании',
#  'Пол',
#  'Возраст',
#  'Образование',
#  'Университет',
#  'Еще.студент',
#  'Уровень.английского',
#  'Предметная.область',
#  'Дата.заполнения',
#  'User.Agent',
#  'exp',
#  'current_job_exp',
#  'salary',
#  'Валюта',
#  'cls']

# %%
#Визначте розмір таблиці за допомогою методу shape строки, стовбці
print('строки, стовбці')
df.shape
# Out:
# строки, стовбці
# (8704, 25)

# %%
df.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
missing_values = df.isnull().sum()
# Підрахунок частки пропущених значень в кожній колонці
total_rows = len(df)
missing_percentage = (missing_values / total_rows) * 100
# Виведемо результати
print("Частка пропусків в кожній колонці:")
print(missing_percentage.round(2))
# Out:
# Частка пропусків в кожній колонці:
# N                                    0.00
# Должность                            0.00
# Язык.программирования               44.23
# Специализация                       82.94
# Общий.опыт.работы                    0.00
# Опыт.работы.на.текущем.месте         0.00
# Зарплата.в.месяц                     0.00
# Изменение.зарплаты.за.12.месяцев     0.00
# Город                                0.00
# Размер.компании                      0.00
# Тип.компании                         0.00
# Пол                                  0.00
# Возраст                              0.00
# Образование                          0.00
# Университет                          4.11
# Еще.студент                          0.00
# Уровень.английского                  0.00
# Предметная.область                   2.56
# Дата.заполнения                      0.00
# User.Agent                           0.00
# exp                                  0.00
# ...

# %%
#Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"
missing_values = df.isnull().sum()
print (df.head(3))
# Out:
#    N           Должность Язык.программирования Специализация  \
# 0  1  Junior QA engineer                   NaN     Manual QA
# 1  2  Junior QA engineer                   NaN     Manual QA
# 2  3   Software Engineer               C#/.NET           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# 1                               130  Харьков  свыше 1000 человек  ...
# 2                               800     Киев     до 1000 человек  ...
#
#   Еще.студент Уровень.английского                    Предметная.область  \
# 0        True       ниже среднего                         iOS,eCommerce
# ...

# %%
df.columns.tolist()
# Out:
# ['N',
#  'Должность',
#  'Язык.программирования',
#  'Специализация',
#  'Общий.опыт.работы',
#  'Опыт.работы.на.текущем.месте',
#  'Зарплата.в.месяц',
#  'Изменение.зарплаты.за.12.месяцев',
#  'Город',
#  'Размер.компании',
#  'Тип.компании',
#  'Пол',
#  'Возраст',
#  'Образование',
#  'Университет',
#  'Еще.студент',
#  'Уровень.английского',
#  'Предметная.область',
#  'Дата.заполнения',
#  'User.Agent',
#  'exp',
#  'current_job_exp',
#  'salary',
#  'Валюта',
#  'cls']

# %%
columns_to_keep = ['Язык.программирования']
columns_with_nulls = df_copy.columns[df.isnull().any()].tolist()
columns_to_drop = [col for col in columns_with_nulls if col not in columns_to_keep]

df_copy.drop(columns=columns_to_drop, inplace=True)

print(df_copy)
# Out:
#          N                 Должность Язык.программирования Общий.опыт.работы  \
# 0        1        Junior QA engineer                   NaN               0.5
# 1        2        Junior QA engineer                   NaN  меньше 3 месяцев
# 2        3         Software Engineer               C#/.NET                 4
# 3        4         Software Engineer            JavaScript                 5
# 4        5  Senior Software Engineer            JavaScript    10 и более лет
# ...    ...                       ...                   ...               ...
# 8699  8700               QA engineer                   NaN                 1
# 8700  8701                 Marketing                   NaN               0.5
# 8701  8702  Junior Software Engineer            Ruby/Rails                 1
# 8702  8703                 Team lead                   NaN                 6
# 8703  8704  Senior Software Engineer                  Java                 7
#
# ...

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
missing_values = df_copy.isnull().sum()
# Підрахунок частки пропущених значень в кожній колонці
total_rows = len(df_copy)
missing_percentage = (missing_values / total_rows) * 100
# Виведемо результати
print("Частка пропусків в кожній колонці:")
print(missing_percentage.round(2))
# Out:
# Частка пропусків в кожній колонці:
# N                                    0.00
# Должность                            0.00
# Язык.программирования               44.23
# Общий.опыт.работы                    0.00
# Опыт.работы.на.текущем.месте         0.00
# Зарплата.в.месяц                     0.00
# Изменение.зарплаты.за.12.месяцев     0.00
# Город                                0.00
# Размер.компании                      0.00
# Тип.компании                         0.00
# Пол                                  0.00
# Возраст                              0.00
# Образование                          0.00
# Еще.студент                          0.00
# Уровень.английского                  0.00
# Дата.заполнения                      0.00
# User.Agent                           0.00
# exp                                  0.00
# current_job_exp                      0.00
# salary                               0.00
# dtype: float64

# %%
df_copy.drop(df_copy.index, inplace=True)

# %%
list(df.head())
# Out:
# ['N',
#  'Должность',
#  'Язык.программирования',
#  'Специализация',
#  'Общий.опыт.работы',
#  'Опыт.работы.на.текущем.месте',
#  'Зарплата.в.месяц',
#  'Изменение.зарплаты.за.12.месяцев',
#  'Город',
#  'Размер.компании',
#  'Тип.компании',
#  'Пол',
#  'Возраст',
#  'Образование',
#  'Университет',
#  'Еще.студент',
#  'Уровень.английского',
#  'Предметная.область',
#  'Дата.заполнения',
#  'User.Agent',
#  'exp',
#  'current_job_exp',
#  'salary',
#  'Валюта',
#  'cls']

# %%
#Визначте розмір таблиці за допомогою методу shape строки, стовбці
print('строки, стовбці')
df.shape
# Out:
# строки, стовбці
# (8704, 25)

# %%
#Визначте новий розмір таблиці за допомогою методу shape
print('строки, стовбці')
df_copy.shape
# Out:
# строки, стовбці
# (0, 20)

# %%
#Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python
python_data=pd.DataFrame()
python_data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2017_jun_final.csv')
python_data = python_data[python_data['Язык.программирования'].notnull()]

# %%
#Визначте розмір таблиці python_data за допомогою методу shape
print('строки, стовбці')
python_data.shape
# Out:
# строки, стовбці
# (4854, 25)

# %%
#Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
missing_values = python_data.isnull().sum()
# Підрахунок частки пропущених значень в кожній колонці
total_rows = len(python_data)
missing_percentage = (missing_values / total_rows) * 100
# Виведемо результати
print("Частка пропусків в кожній колонці:")
print(missing_percentage.round(2))
# Out:
# Частка пропусків в кожній колонці:
# N                                    0.00
# Должность                            0.00
# Язык.программирования                0.00
# Специализация                       99.98
# Общий.опыт.работы                    0.00
# Опыт.работы.на.текущем.месте         0.00
# Зарплата.в.месяц                     0.00
# Изменение.зарплаты.за.12.месяцев     0.00
# Город                                0.00
# Размер.компании                      0.00
# Тип.компании                         0.00
# Пол                                  0.00
# Возраст                              0.00
# Образование                          0.00
# Университет                          4.76
# Еще.студент                          0.00
# Уровень.английского                  0.00
# Предметная.область                   0.62
# Дата.заполнения                      0.00
# User.Agent                           0.00
# exp                                  0.00
# ...

# %%
#Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"
python_data = df.groupby('Должность')
pd.pivot_table(df, index = ['Должность'])
# Out:
# <ipython-input-32-1610fb757aab>:3: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df, index = ['Должность'])
#                                                       N  current_job_exp  \
# Должность
# Business analyst                            4670.633333         1.435000
# DBA                                         4473.884615         2.288462
# Data Scientist / Data Analyst               3917.468354         1.297468
# Designer                                    5225.098655         1.266816
# DevOps                                      4248.170588         1.604412
# Director of Engineering / Program Director  4488.204545         4.284091
# ERP / CRM                                   3575.000000         1.479167
# Game designer                               5287.055556         1.319444
# ...

# %%
#Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"
table_data=pd.DataFrame()
table_data=df.copy(python_data)
table_data = df.groupby('Должность')
pd.pivot_table(df, index = ['Должность'])
# Out:
# <ipython-input-43-efd4ae93ff95>:5: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df.round(3), index = ['Должность'])
#                                                       N  current_job_exp  \
# Должность
# Business analyst                            4670.633333         1.435000
# DBA                                         4473.884615         2.288462
# Data Scientist / Data Analyst               3917.468354         1.297468
# Designer                                    5225.098655         1.266816
# DevOps                                      4248.170588         1.604412
# Director of Engineering / Program Director  4488.204545         4.284091
# ERP / CRM                                   3575.000000         1.479167
# Game designer                               5287.055556         1.319444
# ...

# %%
agg_func_math = {
    'Зарплата.в.месяц': ['min', 'max']
}
df.groupby(['Должность']).agg(agg_func_math).round(2)
# Out:
#                                            Зарплата.в.месяц
#                                                         min    max
# Должность
# Business analyst                                        200   5000
# DBA                                                     380   6000
# Data Scientist / Data Analyst                           150   8000
# Designer                                                100   4000
# DevOps                                                  194  10000
# Director of Engineering / Program Director             1500  34000
# ERP / CRM                                               100   6000
# Game designer                                           150   6800
# HR                                                      100   7000
# HTML coder                                              154   3000
# Junior QA engineer                                       96   2000
# Junior Software Engineer                                 75   2600
# ...

# %%
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"
fill_avg_salary = {
    'Зарплата.в.месяц': 'median'
}
result = df.groupby(['Должность']).agg(fill_avg_salary)
print(result)
# Out:
#                                             Зарплата.в.месяц
# Должность
# Business analyst                                      1340.0
# DBA                                                   1300.0
# Data Scientist / Data Analyst                         1200.0
# Designer                                               800.0
# DevOps                                                2000.0
# Director of Engineering / Program Director            4600.0
# ERP / CRM                                             1100.0
# Game designer                                         1000.0
# HR                                                     700.0
# HTML coder                                             480.5
# Junior QA engineer                                     400.0
# Junior Software Engineer                               550.0
# Marketing                                              617.5
# Product Manager                                       1900.0
# ...

# %%
def fill_avg_salary(row):
  return np.mean(df['Зарплата.в.месяц'])

df['avg'] = df.apply(fill_avg_salary, axis=1)

list(table_data.head())
# Out:
# ['N',
#  'Должность',
#  'Язык.программирования',
#  'Специализация',
#  'Общий.опыт.работы',
#  'Опыт.работы.на.текущем.месте',
#  'Зарплата.в.месяц',
#  'Изменение.зарплаты.за.12.месяцев',
#  'Город',
#  'Размер.компании',
#  'Тип.компании',
#  'Пол',
#  'Возраст',
#  'Образование',
#  'Университет',
#  'Еще.студент',
#  'Уровень.английского',
#  'Предметная.область',
#  'Дата.заполнения',
#  'User.Agent',
#  'exp',
#  'current_job_exp',
#  'salary',
#  'Валюта',
#  'cls',
#  'avg']

# %%
def fill_avg_salary(row):
    return np.mean(row['Зарплата.в.месяц'])

df['avg'] = df.apply(fill_avg_salary, axis=1)
result = df.groupby('Должность')['Зарплата.в.месяц'].agg(avg='mean').reset_index()
print(result)
# Out:
#                                      Должность          avg
# 0                             Business analyst  1551.500000
# 1                                          DBA  1653.269231
# 2                Data Scientist / Data Analyst  1544.240506
# 3                                     Designer  1134.161435
# 4                                       DevOps  2162.688235
# 5   Director of Engineering / Program Director  5066.363636
# 6                                    ERP / CRM  1370.833333
# 7                                Game designer  1455.277778
# 8                                           HR   850.283401
# 9                                   HTML coder   550.993590
# 10                          Junior QA engineer   482.774752
# 11                    Junior Software Engineer   605.658594
# 12                                   Marketing   861.282609
# 13                             Product Manager  2054.471264
# 14                             Project manager  1512.846361
# ...

# %%
#Створіть описову статистику за допомогою методу describe для нового стовпчика.
df['avg']. describe ()
# Out:
# count     8704.000000
# mean      1666.704159
# std       1338.280986
# min         75.000000
# 25%        600.000000
# 50%       1300.000000
# 75%       2400.000000
# max      34000.000000
# Name: avg, dtype: float64

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/proverka.csv')
